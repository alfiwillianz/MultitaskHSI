# %% [markdown]
# # 01c Classification Only - Standard Optimizer
#
# This notebook uses **classification only** (no reconstruction task).
#
# **Key Changes:**
# - Removed reconstruction task and decoder
# - Uses standard `AdamW` optimizer
# - Only classification loss with Focal Loss
# - Still uses masked input for robustness

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GroupShuffleSplit, StratifiedGroupKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
import scipy.io
import requests
import os
from typing import Tuple, Dict, List
import random
import copy
import warnings
from pprint import pprint
import json

warnings.filterwarnings("ignore", category=UserWarning)

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class HyperspectralDataset(Dataset):
    """Custom Dataset for Hyperspectral Data"""

    def __init__(self, data: np.ndarray, labels: np.ndarray, mask_ratio: float = 0.15):
        """
        Args:
            data: Hyperspectral data (N_samples, N_bands)
            labels: Class labels (N_samples,)
            mask_ratio: Ratio of spectral bands to mask for reconstruction task
        """
        self.data = torch.FloatTensor(data)
        self.labels = torch.LongTensor(labels)
        self.mask_ratio = mask_ratio
        self.n_bands = data.shape[1]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        spectrum = self.data[idx]
        label = self.labels[idx]

        # Create masked spectrum for reconstruction task
        masked_spectrum = spectrum.clone()
        n_mask = int(self.n_bands * self.mask_ratio)

        # Random masking
        mask_indices = torch.randperm(self.n_bands)[:n_mask]
        mask = torch.zeros(self.n_bands, dtype=torch.bool)
        mask[mask_indices] = True

        masked_spectrum[mask] = 0.0  # or use learnable mask token

        return {
            'spectrum': spectrum,
            'masked_spectrum': masked_spectrum,
            'mask': mask,
            'label': label
        }

# %%
class PCGrad():
    def __init__(self, optimizer, reduction='mean'):
        self._optim, self._reduction = optimizer, reduction
        return

    @property
    def optimizer(self):
        return self._optim

    def zero_grad(self):
        '''
        clear the gradient of the parameters
        '''

        return self._optim.zero_grad(set_to_none=True)

    def step(self):
        '''
        update the parameters with the gradient
        '''

        return self._optim.step()

    def pc_backward(self, objectives):
        '''
        calculate the gradient of the parameters

        input:
        - objectives: a list of objectives
        '''

        grads, shapes, has_grads = self._pack_grad(objectives)
        pc_grad = self._project_conflicting(grads, has_grads)
        pc_grad = self._unflatten_grad(pc_grad, shapes[0])
        self._set_grad(pc_grad)
        return

    def _project_conflicting(self, grads, has_grads, shapes=None):
        shared = torch.stack(has_grads).prod(0).bool()
        pc_grad, num_task = copy.deepcopy(grads), len(grads)
        for g_i in pc_grad:
            random.shuffle(grads)
            for g_j in grads:
                g_i_g_j = torch.dot(g_i, g_j)
                if g_i_g_j < 0:
                    g_i -= (g_i_g_j) * g_j / (g_j.norm()**2)
        merged_grad = torch.zeros_like(grads[0]).to(grads[0].device)
        if self._reduction:
            merged_grad[shared] = torch.stack([g[shared]
                                           for g in pc_grad]).mean(dim=0)
        elif self._reduction == 'sum':
            merged_grad[shared] = torch.stack([g[shared]
                                           for g in pc_grad]).sum(dim=0)
        else: exit('invalid reduction method')

        merged_grad[~shared] = torch.stack([g[~shared]
                                            for g in pc_grad]).sum(dim=0)
        return merged_grad

    def _set_grad(self, grads):
        '''
        set the modified gradients to the network
        '''

        idx = 0
        for group in self._optim.param_groups:
            for p in group['params']:
                # if p.grad is None: continue
                p.grad = grads[idx]
                idx += 1
        return

    def _pack_grad(self, objectives):
        '''
        pack the gradient of the parameters of the network for each objective
        
        output:
        - grad: a list of the gradient of the parameters
        - shape: a list of the shape of the parameters
        - has_grad: a list of mask represent whether the parameter has gradient
        '''

        grads, shapes, has_grads = [], [], []
        for obj in objectives:
            self._optim.zero_grad(set_to_none=True)
            obj.backward(retain_graph=True)
            grad, shape, has_grad = self._retrieve_grad()
            grads.append(self._flatten_grad(grad, shape))
            has_grads.append(self._flatten_grad(has_grad, shape))
            shapes.append(shape)
        return grads, shapes, has_grads

    def _unflatten_grad(self, grads, shapes):
        unflatten_grad, idx = [], 0
        for shape in shapes:
            length = np.prod(shape)
            unflatten_grad.append(grads[idx:idx + length].view(shape).clone())
            idx += length
        return unflatten_grad

    def _flatten_grad(self, grads, shapes):
        flatten_grad = torch.cat([g.flatten() for g in grads])
        return flatten_grad

    def _retrieve_grad(self):
        '''
        get the gradient of the parameters of the network with specific 
        objective
        
        output:
        - grad: a list of the gradient of the parameters
        - shape: a list of the shape of the parameters
        - has_grad: a list of mask represent whether the parameter has gradient
        '''

        grad, shape, has_grad = [], [], []
        for group in self._optim.param_groups:
            for p in group['params']:
                # if p.grad is None: continue
                # tackle the multi-head scenario
                if p.grad is None:
                    shape.append(p.shape)
                    grad.append(torch.zeros_like(p).to(p.device))
                    has_grad.append(torch.zeros_like(p).to(p.device))
                    continue
                shape.append(p.grad.shape)
                grad.append(p.grad.clone())
                has_grad.append(torch.ones_like(p).to(p.device))
        return grad, shape, has_grad

# %%
class Encoder(nn.Module):
    """Encoder for feature extraction (classification only)"""

    def __init__(self, input_dim: int, latent_dim: int, hidden_dims: List[int] = [256, 128]):
        super(Encoder, self).__init__()

        layers = []
        prev_dim = input_dim

        for hidden_dim in hidden_dims:
            layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.BatchNorm1d(hidden_dim),
                nn.ReLU(),
                nn.Dropout(0.2)
            ])
            prev_dim = hidden_dim

        self.encoder_layers = nn.Sequential(*layers)

        # Latent bottleneck
        self.fc_latent = nn.Linear(prev_dim, latent_dim)

    def forward(self, x):
        h = self.encoder_layers(x)  # high-level features
        z = self.fc_latent(h)        # latent representation
        return h, z

# %%
class ClassificationHead(nn.Module):
    """Classification head"""

    def __init__(self, feature_dim: int, num_classes: int):
        super(ClassificationHead, self).__init__()
        self.classifier = nn.Sequential(
            nn.Linear(feature_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        return self.classifier(x)

# %%
class ClassificationModel(nn.Module):
    """Classification-only model (no reconstruction)"""

    def __init__(self, input_dim: int, latent_dim: int, num_classes: int, hidden_dims: List[int] = [256, 128]):
        super(ClassificationModel, self).__init__()

        self.encoder = Encoder(input_dim, latent_dim, hidden_dims)
        self.classifier = ClassificationHead(hidden_dims[-1], num_classes)

    def forward(self, x):
        h, z = self.encoder(x)  # h: high-level features, z: latent representation
        class_logits = self.classifier(h)
        return {
            'class_logits': class_logits,
            'z': z,
            'features': h
        }

# %%
class FocalLoss(nn.Module):
    """Focal Loss for addressing class imbalance"""
    
    def __init__(self, alpha=1, gamma=2, weight=None, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.weight = weight
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, weight=self.weight, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# Check if data directory exists and list available CSV files
import os
import pandas as pd

data_dir = "../data/"
if os.path.exists(data_dir):
    csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
    print("Available CSV files:")
    for file in sorted(csv_files):
        print(f"  {file}")
else:
    print(f"Data directory '{data_dir}' not found!")
    print("Please ensure the data directory exists with CSV files.")
# Out:
# Available CSV files:
#   df_field_b.csv
#   df_field_g.csv
#   df_screenh_b.csv
#   df_screenh_g.csv

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

def load_dataset_from_csv():
    """
    Load dataset from CSV files in ../data/ directory (pre-merged train/test data)
    
    Returns:
        X_train, X_test, y_train, y_test, groups_train, groups_test, scaler
    """
    
    # List all available CSV files
    csv_files = ['df_field_b.csv', 'df_field_g.csv', 'df_screenh_b.csv', 'df_screenh_g.csv']
    
    X_list = []
    y_list = []
    groups_list = []
    
    print("Loading data from CSV files...")
    
    for file in csv_files:
        file_path = f"../data/{file}"
        if not os.path.exists(file_path):
            print(f"Warning: File {file_path} not found, skipping...")
            continue
            
        print(f"Loading {file}...")
        df = pd.read_csv(file_path, low_memory=False)
        
        # Get spectral columns (all numeric columns except 'y' and 'plant')
        spectral_cols = [col for col in df.columns if col not in ['y', 'plant']]
        
        # Extract features, labels, and groups
        X = df[spectral_cols].values
        y = df['y'].values
        groups = df['plant'].values
        
        # Convert groups to string to handle mixed types before counting unique values
        groups = np.array([str(g) for g in groups])
        
        print(f"  Shape: {X.shape}, Classes: {np.unique(y)}, Groups: {len(np.unique(groups))}")
        
        X_list.append(X)
        y_list.append(y)
        groups_list.append(groups)
    
    if not X_list:
        raise ValueError("No CSV files found or loaded successfully!")
    
    # Combine all data
    X_combined = np.vstack(X_list)
    y_combined = np.hstack(y_list)
    groups_combined = np.hstack(groups_list)
    
    print(f"\nCombined data shape: {X_combined.shape}")
    print(f"Combined classes: {np.unique(y_combined)}")
    print(f"Total groups: {len(np.unique(groups_combined))}")
    
    # Remove any NaN values
    valid_mask = ~(np.isnan(X_combined).any(axis=1) | np.isnan(y_combined))
    X_combined = X_combined[valid_mask]
    y_combined = y_combined[valid_mask]
    groups_combined = groups_combined[valid_mask]
    
    print(f"After removing NaN - Data shape: {X_combined.shape}")
    
    # Convert labels to start from 0 (if they don't already)
    unique_labels = np.unique(y_combined)
    print(f"Original label range: {unique_labels}")
    
    if unique_labels.min() != 0:
        print("Converting labels to start from 0...")
        label_mapping = {old_label: new_label for new_label, old_label in enumerate(sorted(unique_labels))}
        y_combined = np.array([label_mapping[label] for label in y_combined])
        print(f"New label range: {np.unique(y_combined)}")
    
    # Split into train and test using GroupShuffleSplit
    from sklearn.model_selection import GroupShuffleSplit
    
    gss = GroupShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
    train_idx, test_idx = next(gss.split(X_combined, y_combined, groups_combined))
    
    X_train, X_test = X_combined[train_idx], X_combined[test_idx]
    y_train, y_test = y_combined[train_idx], y_combined[test_idx]
    groups_train, groups_test = groups_combined[train_idx], groups_combined[test_idx]
    
    # Normalize features using StandardScaler
    scaler = StandardScaler()
    X_train_norm = scaler.fit_transform(X_train.astype(np.float32))
    X_test_norm = scaler.transform(X_test.astype(np.float32))
    
    print(f"Spectral bands/features: {X_train_norm.shape[1]}")
    print(f"Training samples: {X_train_norm.shape[0]}")
    print(f"Test samples: {X_test_norm.shape[0]}")
    print(f"Training classes: {np.unique(y_train)}")
    print(f"Test classes: {np.unique(y_test)}")
    
    return X_train_norm, X_test_norm, y_train.astype(np.int32), y_test.astype(np.int32), groups_train, groups_test, scaler

# Legacy function for backward compatibility
def load_dataset(data_path=None, gt_path=None):
    """Legacy function - now loads from CSV files instead of MATLAB files"""
    print("Note: load_dataset now loads from CSV files in ../data/ directory")
    X_train, X_test, y_train, y_test, groups_train, groups_test, scaler = load_dataset_from_csv()

    # Combine train and test for backward compatibility
    X_combined = np.vstack([X_train, X_test])
    y_combined = np.hstack([y_train, y_test])
    groups_combined = np.hstack([groups_train, groups_test])

    return X_combined, y_combined, groups_combined, scaler

def split(X, y, groups, test_size=0.2, random_state=42):
    """Split dataset into training and validation sets using GroupShuffleSplit"""
    gss = GroupShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    train_idx, val_idx = next(gss.split(X, y, groups))

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    groups_train, groups_val = groups[train_idx], groups[val_idx]

    print(f"Training samples: {X_train.shape[0]}, Validation samples: {X_val.shape[0]}")
    return X_train, X_val, y_train, y_val, groups_train, groups_val

# %%
def prepare_data(n_splits=5):
    """Load and prepare dataset for StratifiedGroupKFold cross-validation"""
    print("Loading dataset...")
    data, labels, groups, scaler = load_dataset()
    
    labels = np.array([int(str(label).replace('O', '0')) for label in labels])
    labels = labels.astype(np.int32)
    groups = np.array([str(group).replace('O', '0') for group in groups])
    groups = groups.astype(np.int32)

    print(f"Total samples: {data.shape[0]}")
    print(f"Using StratifiedGroupKFold with {n_splits} folds")

    return data, labels, groups, scaler

def split_data(X, y, groups, test_size=0.3, random_state=42):
    """Split dataset into training and validation sets using GroupShuffleSplit"""
    gss = GroupShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    train_idx, val_idx = next(gss.split(X, y, groups))

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    groups_train, groups_val = groups[train_idx], groups[val_idx]

    print(f"Training samples: {X_train.shape[0]}, Validation samples: {X_val.shape[0]}")
    return X_train, X_val, y_train, y_val, groups_train, groups_val


def create_dataloaders(X_train, X_val, y_train, y_val, batch_size=64, mask_ratio=0.15):
    """Create datasets and dataloaders for a single fold"""
    train_dataset = HyperspectralDataset(X_train, y_train, mask_ratio=mask_ratio)
    val_dataset = HyperspectralDataset(X_val, y_val, mask_ratio=mask_ratio)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader


def setup_model_and_optimizer(input_dim, num_classes, latent_dim=64, lr=1e-3):
    """Initialize model, optimizer, and scheduler - classification only"""
    model = ClassificationModel(input_dim, latent_dim, num_classes).to(device)
    print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")

    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=10
    )

    return model, optimizer, scheduler


def setup_loss_functions(y_train):
    """Initialize loss functions with class weights"""
    class_counts = np.bincount(y_train)
    class_weights = 1.0 / class_counts
    class_weights = class_weights / class_weights.sum() * len(class_weights)
    class_weights_tensor = torch.FloatTensor(class_weights).to(device)
    
    focal_loss = FocalLoss(alpha=1, gamma=2, weight=class_weights_tensor, reduction='mean')
    print(f"Using Focal Loss with class weights: {class_weights}")
    
    return focal_loss


def train_epoch(model, train_loader, optimizer, focal_loss):
    """Single training epoch - classification only"""
    model.train()
    train_loss_epoch = 0
    train_correct = train_total = 0

    for batch in train_loader:
        masked_spectrum = batch['masked_spectrum'].to(device)
        labels_batch = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(masked_spectrum)

        class_loss = focal_loss(outputs['class_logits'], labels_batch)
        
        class_loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        train_loss_epoch += class_loss.item()

        _, predicted = torch.max(outputs['class_logits'].data, 1)
        train_total += labels_batch.size(0)
        train_correct += (predicted == labels_batch).sum().item()

    return {
        'loss': train_loss_epoch / len(train_loader),
        'accuracy': 100 * train_correct / train_total
    }


def validate_epoch(model, val_loader, focal_loss):
    """Single validation epoch - classification only"""
    model.eval()
    val_loss_epoch = 0
    val_correct = val_total = 0
    val_predictions = []
    val_targets = []

    with torch.no_grad():
        for batch in val_loader:
            masked_spectrum = batch['masked_spectrum'].to(device)
            labels_batch = batch['label'].to(device)

            outputs = model(masked_spectrum)
            class_loss = focal_loss(outputs['class_logits'], labels_batch)

            val_loss_epoch += class_loss.item()

            _, predicted = torch.max(outputs['class_logits'].data, 1)
            val_total += labels_batch.size(0)
            val_correct += (predicted == labels_batch).sum().item()
            
            val_predictions.extend(predicted.cpu().numpy())
            val_targets.extend(labels_batch.cpu().numpy())

    return {
        'loss': val_loss_epoch / len(val_loader),
        'accuracy': 100 * val_correct / val_total,
        'f1_score': f1_score(val_targets, val_predictions, average='weighted')
    }


def plot_training_results(history, test_targets, test_predictions, output_dir='./Class'):
    """Plot training curves and confusion matrix - classification only"""
    plt.figure(figsize=(15, 5))

    # 1. Classification Loss
    plt.subplot(1, 3, 1)
    plt.plot(history['train_losses'], label='Train Loss')
    plt.plot(history['val_losses'], label='Val Loss')
    plt.title('Classification Loss (Focal Loss)')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # 2. Train-Val Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(history['train_accuracies'], label='Train Acc')
    plt.plot(history['val_accuracies'], label='Val Acc')
    plt.title('Train-Val Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    # 3. Confusion Matrix
    plt.subplot(1, 3, 3)
    cm = confusion_matrix(test_targets, test_predictions)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')

    plt.tight_layout()
    plt.show()
    os.makedirs(output_dir, exist_ok=True)
    plt.savefig(f'{output_dir}/training_curves_classification.png')
    print(f"✅ Training plot saved to {output_dir}/training_curves_classification.png")


def train_classification_model(epochs=100, batch_size=64, latent_dim=64, 
                              patience=15, output_dir='./Class', n_splits=5):
    """Main training function - classification only with StratifiedGroupKFold cross-validation"""
    
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Prepare data
    X, y, groups, scaler = prepare_data(n_splits=n_splits)

    # 1.1 Split data into train and test
    X, X_test, y, y_test, groups, groups_test = split_data(X, y, groups, test_size=0.3)
    
    # 2. Setup StratifiedGroupKFold
    sgkf = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    # 3. Setup model parameters
    input_dim = X.shape[1]
    num_classes = len(np.unique(y))
    
    # Storage for test set predictions
    test_predictions_per_fold = []
    test_features_per_fold = []
    fold_histories = []
    fold_metrics = []
    metric = {}
    
    print(f"\nInput: {input_dim}, Classes: {num_classes}, Latent: {latent_dim}")
    print(f"Starting {n_splits}-fold cross-validation training (Classification Only)...\n")
    print(f"Test set size: {X_test.shape[0]} samples\n")
    
    for fold, (train_idx, val_idx) in enumerate(sgkf.split(X, y, groups)):
        print(f"\n{'='*60}")
        print(f"Fold {fold + 1}/{n_splits}")
        print(f"{'='*60}")
        
        # Split data for this fold
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        
        print(f"Train samples: {X_train.shape[0]}, Val samples: {X_val.shape[0]}")
        
        # Create dataloaders
        train_loader, val_loader = create_dataloaders(
            X_train, X_val, y_train, y_val, batch_size=batch_size
        )
        
        # Setup model and optimizer for this fold
        model, optimizer, scheduler = setup_model_and_optimizer(
            input_dim, num_classes, latent_dim
        )
        
        # Setup loss functions
        focal_loss = setup_loss_functions(y_train)
        
        # Training loop for this fold
        history = {
            'train_losses': [], 'val_losses': [],
            'train_accuracies': [], 'val_accuracies': []
        }
        
        best_val_loss = float('inf')
        best_epoch = 0
        best_metrics = {}
        patience_counter = 0
        
        for epoch in range(epochs):
            train_metrics = train_epoch(model, train_loader, optimizer, focal_loss)
            val_metrics = validate_epoch(model, val_loader, focal_loss)
            
            history['train_losses'].append(train_metrics['loss'])
            history['val_losses'].append(val_metrics['loss'])
            history['train_accuracies'].append(train_metrics['accuracy'])
            history['val_accuracies'].append(val_metrics['accuracy'])
            
            scheduler.step(val_metrics['loss'])
            
            if val_metrics['loss'] < best_val_loss:
                best_val_loss = val_metrics['loss']
                best_epoch = epoch + 1
                best_metrics = {
                    "val": val_metrics,
                    "train": train_metrics
                }
                patience_counter = 0
                checkpoint_path = f'{output_dir}/best_classification_model_fold{fold+1}.pth'
                torch.save(model.state_dict(), checkpoint_path)
                print(f'Epoch [{epoch+1}/{epochs}] - NEW BEST: Loss: {val_metrics["loss"]:.4f}, Acc: {val_metrics["accuracy"]:.2f}%')
            else:
                patience_counter += 1
            
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}\n")
                break
        
        
        # 4. Evaluate on test set
        checkpoint_path = f'{output_dir}/best_classification_model_fold{fold+1}.pth'
        model.load_state_dict(torch.load(checkpoint_path))
        
        test_dataset = HyperspectralDataset(X_test, y_test, mask_ratio=0.15)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        test_predictions = []
        test_targets = []
        test_features = []
        
        model.eval()
        with torch.no_grad():
            for batch in test_loader:
                masked_spectrum = batch['masked_spectrum'].to(device)
                labels_batch = batch['label'].to(device)
                
                outputs = model(masked_spectrum)
                _, predicted = torch.max(outputs['class_logits'].data, 1)
                
                test_predictions.extend(predicted.cpu().numpy())
                test_targets.extend(labels_batch.cpu().numpy())
                test_features.extend(outputs['features'].cpu().numpy())
        
        test_accuracy = 100 * np.mean(np.array(test_predictions) == np.array(test_targets))
        test_f1 = f1_score(test_targets, test_predictions, average='weighted')
        
        print(f'\nFold {fold + 1} Test Accuracy: {test_accuracy:.2f}%')
        print(f'Fold {fold + 1} Test F1 Score: {test_f1:.4f}')
        
        # Store test predictions and features for each fold
        test_predictions_per_fold.append(test_predictions)
        test_features_per_fold.append(test_features)
        
        fold_histories.append(history)
        fold_metrics.append({
            'fold': fold + 1,
            'accuracy': test_accuracy,
            'f1_score': test_f1
        })
        
        metric[f'fold_{fold+1}'] = best_metrics
        
    pprint(metric)
    
    with open(f'{output_dir}/classification_fold_metrics.json', 'w') as f:
        json.dump(metric, f, indent=4)

    # 5. Calculate overall test metrics (ensemble from all folds)
    test_predictions_ensemble_hard = np.round(np.mean(test_predictions_per_fold, axis=0)).astype(int)
    
    overall_test_accuracy = 100 * np.mean(test_predictions_ensemble_hard == test_targets)
    overall_test_f1 = f1_score(test_targets, test_predictions_ensemble_hard, average='weighted')
    
    print(f"\n{'='*60}")
    print("Overall Test Results (5-Fold Ensemble)")
    print(f"{'='*60}")
    print(f'Overall Test Accuracy: {overall_test_accuracy:.2f}%')
    print(f'Overall Test F1 Score: {overall_test_f1:.4f}')
    print('\nTest Classification Report:')
    print(classification_report(test_targets, test_predictions_ensemble_hard))

    # Save classification report to csv
    report = classification_report(test_targets, test_predictions_ensemble_hard, output_dict=True)
    report_df = pd.DataFrame(report).transpose()
    report_df.to_csv(f'{output_dir}/classification_report.csv', index=True)
    print(f"✅ Classification report saved to {output_dir}/classification_report.csv")
    
    # Plot results from first fold as representative
    plot_training_results(fold_histories[0], test_targets, test_predictions_ensemble_hard, output_dir)
    
    return model, (test_features_per_fold, test_targets, test_predictions_ensemble_hard), scaler

# %%
# Clear any existing model and restart training cleanly
import gc
import torch

# Clear GPU memory if available
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# Force garbage collection
gc.collect()

print("Memory cleared. Starting fresh training (Classification Only)...\n")

# Train the model with configurable parameters
model, test_results, scaler = train_classification_model(
    epochs=500,
    batch_size=64,
    latent_dim=64,
    patience=15,
    output_dir='./Class',
    n_splits=5
)

print("\nTraining completed successfully!")
print(f"Best models saved for classification task")

# Feature analysis
features_list, targets, predictions = test_results
print(f"Collected features from {len(features_list)} folds")
print(f"Predictions shape: {np.array(predictions).shape}")
print("Using Focal Loss for classification with StratifiedGroupKFold cross-validation")
# Out:
# Memory cleared. Starting fresh training (Classification Only)...
#
# Loading dataset...
# Note: load_dataset now loads from CSV files in ../data/ directory
# Loading data from CSV files...
# Loading df_field_b.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_field_g.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_field_g.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_screenh_b.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_screenh_b.csv...
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 11
# Loading df_screenh_g.csv...
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 11
# Loading df_screenh_g.csv...
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 10
#
# Combined data shape: (15718, 2550)
# Combined classes: [0 1 2]
# Total groups: 11
# After removing NaN - Data shape: (15718, 2550)
# Original label range: [0 1 2]
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 10
#
# Combined data shape: (15718, 2550)
# Combined classes: [0 1 2]
# Total groups: 11
# After removing NaN - Data shape: (15718, 2550)
# Original label range: [0 1 2]
# Spectral bands/features: 2550
# Training samples: 9364
# Test samples: 6354
# Training classes: [0 1 2]
# Test classes: [0 1 2]
# Total samples: 15718
# Using StratifiedGroupKFold with 5 folds
# Training samples: 10996, Validation samples: 4722
#
# Input: 2550, Classes: 3, Latent: 64
# Starting 5-fold cross-validation training (Classification Only)...
#
# Test set size: 4722 samples
#
#
# ============================================================
# Fold 1/5
# ============================================================
# Train samples: 9370, Val samples: 1626
# Model parameters: 712,131
# Spectral bands/features: 2550
# Training samples: 9364
# Test samples: 6354
# Training classes: [0 1 2]
# Test classes: [0 1 2]
# Total samples: 15718
# Using StratifiedGroupKFold with 5 folds
# Training samples: 10996, Validation samples: 4722
#
# Input: 2550, Classes: 3, Latent: 64
# Starting 5-fold cross-validation training (Classification Only)...
#
# Test set size: 4722 samples
#
#
# ============================================================
# Fold 1/5
# ============================================================
# Train samples: 9370, Val samples: 1626
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.67408216 1.20777696 1.11814088]
# Using Focal Loss with class weights: [0.67408216 1.20777696 1.11814088]
# Epoch [1/500] - NEW BEST: Loss: 0.3795, Acc: 44.59%
# Epoch [1/500] - NEW BEST: Loss: 0.3795, Acc: 44.59%
# Epoch [2/500] - NEW BEST: Loss: 0.3468, Acc: 49.51%
# Epoch [2/500] - NEW BEST: Loss: 0.3468, Acc: 49.51%
# Epoch [3/500] - NEW BEST: Loss: 0.3261, Acc: 54.24%
# Epoch [3/500] - NEW BEST: Loss: 0.3261, Acc: 54.24%
# Epoch [4/500] - NEW BEST: Loss: 0.2982, Acc: 59.10%
# Epoch [4/500] - NEW BEST: Loss: 0.2982, Acc: 59.10%
# Epoch [6/500] - NEW BEST: Loss: 0.2629, Acc: 64.45%
# Epoch [6/500] - NEW BEST: Loss: 0.2629, Acc: 64.45%
# Epoch [8/500] - NEW BEST: Loss: 0.2531, Acc: 66.24%
# Epoch [8/500] - NEW BEST: Loss: 0.2531, Acc: 66.24%
# Epoch [11/500] - NEW BEST: Loss: 0.2295, Acc: 69.62%
# Epoch [11/500] - NEW BEST: Loss: 0.2295, Acc: 69.62%
# Epoch [13/500] - NEW BEST: Loss: 0.2118, Acc: 68.08%
# Epoch [13/500] - NEW BEST: Loss: 0.2118, Acc: 68.08%
# Epoch [17/500] - NEW BEST: Loss: 0.2051, Acc: 70.66%
# Epoch [17/500] - NEW BEST: Loss: 0.2051, Acc: 70.66%
# Epoch [19/500] - NEW BEST: Loss: 0.1921, Acc: 75.09%
# Epoch [19/500] - NEW BEST: Loss: 0.1921, Acc: 75.09%
# Epoch [25/500] - NEW BEST: Loss: 0.1749, Acc: 76.69%
# Epoch [25/500] - NEW BEST: Loss: 0.1749, Acc: 76.69%
# Epoch [29/500] - NEW BEST: Loss: 0.1715, Acc: 75.34%
# Epoch [29/500] - NEW BEST: Loss: 0.1715, Acc: 75.34%
# Epoch [39/500] - NEW BEST: Loss: 0.1662, Acc: 77.49%
# Epoch [39/500] - NEW BEST: Loss: 0.1662, Acc: 77.49%
# Epoch [42/500] - NEW BEST: Loss: 0.1574, Acc: 78.54%
# Epoch [42/500] - NEW BEST: Loss: 0.1574, Acc: 78.54%
# Epoch [43/500] - NEW BEST: Loss: 0.1559, Acc: 76.57%
# Epoch [43/500] - NEW BEST: Loss: 0.1559, Acc: 76.57%
# Epoch [51/500] - NEW BEST: Loss: 0.1465, Acc: 78.41%
# Epoch [51/500] - NEW BEST: Loss: 0.1465, Acc: 78.41%
# Epoch [53/500] - NEW BEST: Loss: 0.1405, Acc: 78.17%
# Epoch [53/500] - NEW BEST: Loss: 0.1405, Acc: 78.17%
# Epoch [65/500] - NEW BEST: Loss: 0.1280, Acc: 81.61%
# Epoch [65/500] - NEW BEST: Loss: 0.1280, Acc: 81.61%
# Epoch [70/500] - NEW BEST: Loss: 0.1256, Acc: 82.72%
# Epoch [70/500] - NEW BEST: Loss: 0.1256, Acc: 82.72%
# Epoch [72/500] - NEW BEST: Loss: 0.1251, Acc: 83.52%
# Epoch [72/500] - NEW BEST: Loss: 0.1251, Acc: 83.52%
# Epoch [79/500] - NEW BEST: Loss: 0.1220, Acc: 82.72%
# Epoch [79/500] - NEW BEST: Loss: 0.1220, Acc: 82.72%
# Epoch [90/500] - NEW BEST: Loss: 0.1212, Acc: 80.93%
# Epoch [90/500] - NEW BEST: Loss: 0.1212, Acc: 80.93%
# Epoch [100/500] - NEW BEST: Loss: 0.1205, Acc: 85.06%
# Epoch [100/500] - NEW BEST: Loss: 0.1205, Acc: 85.06%
# Early stopping at epoch 115
#
#
# Fold 1 Test Accuracy: 82.78%
# Fold 1 Test F1 Score: 0.8302
#
# ============================================================
# Fold 2/5
# ============================================================
# Train samples: 9376, Val samples: 1620
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.67046774 1.21532746 1.11420479]
# Early stopping at epoch 115
#
#
# Fold 1 Test Accuracy: 82.78%
# Fold 1 Test F1 Score: 0.8302
#
# ============================================================
# Fold 2/5
# ============================================================
# Train samples: 9376, Val samples: 1620
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.67046774 1.21532746 1.11420479]
# Epoch [1/500] - NEW BEST: Loss: 0.3892, Acc: 47.28%
# Epoch [1/500] - NEW BEST: Loss: 0.3892, Acc: 47.28%
# Epoch [2/500] - NEW BEST: Loss: 0.3595, Acc: 52.41%
# Epoch [2/500] - NEW BEST: Loss: 0.3595, Acc: 52.41%
# Epoch [3/500] - NEW BEST: Loss: 0.3262, Acc: 55.62%
# Epoch [3/500] - NEW BEST: Loss: 0.3262, Acc: 55.62%
# Epoch [4/500] - NEW BEST: Loss: 0.3236, Acc: 55.49%
# Epoch [4/500] - NEW BEST: Loss: 0.3236, Acc: 55.49%
# Epoch [5/500] - NEW BEST: Loss: 0.2896, Acc: 65.74%
# Epoch [5/500] - NEW BEST: Loss: 0.2896, Acc: 65.74%
# Epoch [6/500] - NEW BEST: Loss: 0.2737, Acc: 66.42%
# Epoch [6/500] - NEW BEST: Loss: 0.2737, Acc: 66.42%
# Epoch [7/500] - NEW BEST: Loss: 0.2565, Acc: 66.60%
# Epoch [7/500] - NEW BEST: Loss: 0.2565, Acc: 66.60%
# Epoch [10/500] - NEW BEST: Loss: 0.2465, Acc: 60.62%
# Epoch [10/500] - NEW BEST: Loss: 0.2465, Acc: 60.62%
# Epoch [11/500] - NEW BEST: Loss: 0.2366, Acc: 64.69%
# Epoch [11/500] - NEW BEST: Loss: 0.2366, Acc: 64.69%
# Epoch [13/500] - NEW BEST: Loss: 0.2172, Acc: 69.81%
# Epoch [13/500] - NEW BEST: Loss: 0.2172, Acc: 69.81%
# Epoch [15/500] - NEW BEST: Loss: 0.2167, Acc: 65.99%
# Epoch [15/500] - NEW BEST: Loss: 0.2167, Acc: 65.99%
# Epoch [18/500] - NEW BEST: Loss: 0.2126, Acc: 68.15%
# Epoch [18/500] - NEW BEST: Loss: 0.2126, Acc: 68.15%
# Epoch [21/500] - NEW BEST: Loss: 0.2047, Acc: 70.86%
# Epoch [21/500] - NEW BEST: Loss: 0.2047, Acc: 70.86%
# Epoch [26/500] - NEW BEST: Loss: 0.1964, Acc: 71.67%
# Epoch [26/500] - NEW BEST: Loss: 0.1964, Acc: 71.67%
# Epoch [27/500] - NEW BEST: Loss: 0.1956, Acc: 74.07%
# Epoch [27/500] - NEW BEST: Loss: 0.1956, Acc: 74.07%
# Epoch [28/500] - NEW BEST: Loss: 0.1944, Acc: 74.75%
# Epoch [28/500] - NEW BEST: Loss: 0.1944, Acc: 74.75%
# Epoch [29/500] - NEW BEST: Loss: 0.1905, Acc: 72.22%
# Epoch [29/500] - NEW BEST: Loss: 0.1905, Acc: 72.22%
# Epoch [30/500] - NEW BEST: Loss: 0.1870, Acc: 72.47%
# Epoch [30/500] - NEW BEST: Loss: 0.1870, Acc: 72.47%
# Epoch [32/500] - NEW BEST: Loss: 0.1838, Acc: 73.09%
# Epoch [32/500] - NEW BEST: Loss: 0.1838, Acc: 73.09%
# Epoch [35/500] - NEW BEST: Loss: 0.1747, Acc: 75.93%
# Epoch [35/500] - NEW BEST: Loss: 0.1747, Acc: 75.93%
# Epoch [41/500] - NEW BEST: Loss: 0.1659, Acc: 77.22%
# Epoch [41/500] - NEW BEST: Loss: 0.1659, Acc: 77.22%
# Epoch [42/500] - NEW BEST: Loss: 0.1617, Acc: 75.43%
# Epoch [42/500] - NEW BEST: Loss: 0.1617, Acc: 75.43%
# Epoch [46/500] - NEW BEST: Loss: 0.1566, Acc: 78.27%
# Epoch [46/500] - NEW BEST: Loss: 0.1566, Acc: 78.27%
# Epoch [50/500] - NEW BEST: Loss: 0.1539, Acc: 76.73%
# Epoch [50/500] - NEW BEST: Loss: 0.1539, Acc: 76.73%
# Epoch [56/500] - NEW BEST: Loss: 0.1537, Acc: 77.35%
# Epoch [56/500] - NEW BEST: Loss: 0.1537, Acc: 77.35%
# Epoch [64/500] - NEW BEST: Loss: 0.1454, Acc: 79.88%
# Epoch [64/500] - NEW BEST: Loss: 0.1454, Acc: 79.88%
# Epoch [73/500] - NEW BEST: Loss: 0.1381, Acc: 82.28%
# Epoch [73/500] - NEW BEST: Loss: 0.1381, Acc: 82.28%
# Epoch [79/500] - NEW BEST: Loss: 0.1366, Acc: 80.37%
# Epoch [79/500] - NEW BEST: Loss: 0.1366, Acc: 80.37%
# Epoch [93/500] - NEW BEST: Loss: 0.1347, Acc: 83.95%
# Epoch [93/500] - NEW BEST: Loss: 0.1347, Acc: 83.95%
# Epoch [94/500] - NEW BEST: Loss: 0.1298, Acc: 82.22%
# Epoch [94/500] - NEW BEST: Loss: 0.1298, Acc: 82.22%
# Epoch [101/500] - NEW BEST: Loss: 0.1223, Acc: 83.77%
# Epoch [101/500] - NEW BEST: Loss: 0.1223, Acc: 83.77%
# Epoch [116/500] - NEW BEST: Loss: 0.1199, Acc: 85.25%
# Epoch [116/500] - NEW BEST: Loss: 0.1199, Acc: 85.25%
# Epoch [127/500] - NEW BEST: Loss: 0.1189, Acc: 85.99%
# Epoch [127/500] - NEW BEST: Loss: 0.1189, Acc: 85.99%
# Epoch [139/500] - NEW BEST: Loss: 0.1159, Acc: 84.94%
# Epoch [139/500] - NEW BEST: Loss: 0.1159, Acc: 84.94%
# Epoch [141/500] - NEW BEST: Loss: 0.1155, Acc: 85.86%
# Epoch [141/500] - NEW BEST: Loss: 0.1155, Acc: 85.86%
# Early stopping at epoch 156
#
#
# Fold 2 Test Accuracy: 84.54%
# Fold 2 Test F1 Score: 0.8478
#
# ============================================================
# Fold 3/5
# ============================================================
# Train samples: 7788, Val samples: 3208
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.67418408 1.20404333 1.12177259]
# Early stopping at epoch 156
#
#
# Fold 2 Test Accuracy: 84.54%
# Fold 2 Test F1 Score: 0.8478
#
# ============================================================
# Fold 3/5
# ============================================================
# Train samples: 7788, Val samples: 3208
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.67418408 1.20404333 1.12177259]
# Epoch [1/500] - NEW BEST: Loss: 0.3787, Acc: 43.73%
# Epoch [1/500] - NEW BEST: Loss: 0.3787, Acc: 43.73%
# Epoch [2/500] - NEW BEST: Loss: 0.3640, Acc: 52.28%
# Epoch [2/500] - NEW BEST: Loss: 0.3640, Acc: 52.28%
# Epoch [3/500] - NEW BEST: Loss: 0.3457, Acc: 49.66%
# Epoch [3/500] - NEW BEST: Loss: 0.3457, Acc: 49.66%
# Epoch [4/500] - NEW BEST: Loss: 0.3252, Acc: 55.83%
# Epoch [4/500] - NEW BEST: Loss: 0.3252, Acc: 55.83%
# Epoch [5/500] - NEW BEST: Loss: 0.2952, Acc: 60.50%
# Epoch [5/500] - NEW BEST: Loss: 0.2952, Acc: 60.50%
# Epoch [6/500] - NEW BEST: Loss: 0.2852, Acc: 62.66%
# Epoch [6/500] - NEW BEST: Loss: 0.2852, Acc: 62.66%
# Epoch [7/500] - NEW BEST: Loss: 0.2719, Acc: 58.95%
# Epoch [7/500] - NEW BEST: Loss: 0.2719, Acc: 58.95%
# Epoch [8/500] - NEW BEST: Loss: 0.2656, Acc: 63.62%
# Epoch [8/500] - NEW BEST: Loss: 0.2656, Acc: 63.62%
# Epoch [9/500] - NEW BEST: Loss: 0.2573, Acc: 67.46%
# Epoch [9/500] - NEW BEST: Loss: 0.2573, Acc: 67.46%
# Epoch [10/500] - NEW BEST: Loss: 0.2520, Acc: 65.55%
# Epoch [10/500] - NEW BEST: Loss: 0.2520, Acc: 65.55%
# Epoch [11/500] - NEW BEST: Loss: 0.2397, Acc: 67.83%
# Epoch [11/500] - NEW BEST: Loss: 0.2397, Acc: 67.83%
# Epoch [13/500] - NEW BEST: Loss: 0.2298, Acc: 69.54%
# Epoch [13/500] - NEW BEST: Loss: 0.2298, Acc: 69.54%
# Epoch [15/500] - NEW BEST: Loss: 0.2295, Acc: 70.89%
# Epoch [15/500] - NEW BEST: Loss: 0.2295, Acc: 70.89%
# Epoch [16/500] - NEW BEST: Loss: 0.2195, Acc: 69.76%
# Epoch [16/500] - NEW BEST: Loss: 0.2195, Acc: 69.76%
# Epoch [17/500] - NEW BEST: Loss: 0.2092, Acc: 72.41%
# Epoch [17/500] - NEW BEST: Loss: 0.2092, Acc: 72.41%
# Epoch [20/500] - NEW BEST: Loss: 0.2034, Acc: 72.04%
# Epoch [20/500] - NEW BEST: Loss: 0.2034, Acc: 72.04%
# Epoch [22/500] - NEW BEST: Loss: 0.1967, Acc: 73.04%
# Epoch [22/500] - NEW BEST: Loss: 0.1967, Acc: 73.04%
# Epoch [24/500] - NEW BEST: Loss: 0.1901, Acc: 74.00%
# Epoch [24/500] - NEW BEST: Loss: 0.1901, Acc: 74.00%
# Epoch [31/500] - NEW BEST: Loss: 0.1831, Acc: 73.22%
# Epoch [31/500] - NEW BEST: Loss: 0.1831, Acc: 73.22%
# Epoch [34/500] - NEW BEST: Loss: 0.1817, Acc: 74.94%
# Epoch [34/500] - NEW BEST: Loss: 0.1817, Acc: 74.94%
# Epoch [35/500] - NEW BEST: Loss: 0.1763, Acc: 73.04%
# Epoch [35/500] - NEW BEST: Loss: 0.1763, Acc: 73.04%
# Epoch [41/500] - NEW BEST: Loss: 0.1591, Acc: 77.71%
# Epoch [41/500] - NEW BEST: Loss: 0.1591, Acc: 77.71%
# Epoch [47/500] - NEW BEST: Loss: 0.1591, Acc: 76.00%
# Epoch [47/500] - NEW BEST: Loss: 0.1591, Acc: 76.00%
# Epoch [54/500] - NEW BEST: Loss: 0.1564, Acc: 78.21%
# Epoch [54/500] - NEW BEST: Loss: 0.1564, Acc: 78.21%
# Epoch [56/500] - NEW BEST: Loss: 0.1532, Acc: 79.99%
# Epoch [56/500] - NEW BEST: Loss: 0.1532, Acc: 79.99%
# Epoch [60/500] - NEW BEST: Loss: 0.1488, Acc: 78.65%
# Epoch [60/500] - NEW BEST: Loss: 0.1488, Acc: 78.65%
# Epoch [61/500] - NEW BEST: Loss: 0.1478, Acc: 78.30%
# Epoch [61/500] - NEW BEST: Loss: 0.1478, Acc: 78.30%
# Epoch [67/500] - NEW BEST: Loss: 0.1467, Acc: 80.08%
# Epoch [67/500] - NEW BEST: Loss: 0.1467, Acc: 80.08%
# Epoch [68/500] - NEW BEST: Loss: 0.1412, Acc: 78.77%
# Epoch [68/500] - NEW BEST: Loss: 0.1412, Acc: 78.77%
# Epoch [70/500] - NEW BEST: Loss: 0.1408, Acc: 80.27%
# Epoch [70/500] - NEW BEST: Loss: 0.1408, Acc: 80.27%
# Epoch [77/500] - NEW BEST: Loss: 0.1331, Acc: 80.61%
# Epoch [77/500] - NEW BEST: Loss: 0.1331, Acc: 80.61%
# Epoch [89/500] - NEW BEST: Loss: 0.1320, Acc: 82.26%
# Epoch [89/500] - NEW BEST: Loss: 0.1320, Acc: 82.26%
# Epoch [90/500] - NEW BEST: Loss: 0.1194, Acc: 81.20%
# Epoch [90/500] - NEW BEST: Loss: 0.1194, Acc: 81.20%
# Epoch [103/500] - NEW BEST: Loss: 0.1193, Acc: 83.04%
# Epoch [103/500] - NEW BEST: Loss: 0.1193, Acc: 83.04%
# Epoch [104/500] - NEW BEST: Loss: 0.1178, Acc: 83.51%
# Epoch [104/500] - NEW BEST: Loss: 0.1178, Acc: 83.51%
# Epoch [106/500] - NEW BEST: Loss: 0.1168, Acc: 84.01%
# Epoch [106/500] - NEW BEST: Loss: 0.1168, Acc: 84.01%
# Epoch [121/500] - NEW BEST: Loss: 0.1162, Acc: 83.92%
# Epoch [121/500] - NEW BEST: Loss: 0.1162, Acc: 83.92%
# Epoch [122/500] - NEW BEST: Loss: 0.1094, Acc: 84.66%
# Epoch [122/500] - NEW BEST: Loss: 0.1094, Acc: 84.66%
# Early stopping at epoch 137
#
#
# Fold 3 Test Accuracy: 83.21%
# Fold 3 Test F1 Score: 0.8345
#
# ============================================================
# Fold 4/5
# ============================================================
# Train samples: 9378, Val samples: 1618
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.6694741  1.21217071 1.1183552 ]
# Early stopping at epoch 137
#
#
# Fold 3 Test Accuracy: 83.21%
# Fold 3 Test F1 Score: 0.8345
#
# ============================================================
# Fold 4/5
# ============================================================
# Train samples: 9378, Val samples: 1618
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.6694741  1.21217071 1.1183552 ]
# Epoch [1/500] - NEW BEST: Loss: 0.3633, Acc: 49.26%
# Epoch [1/500] - NEW BEST: Loss: 0.3633, Acc: 49.26%
# Epoch [2/500] - NEW BEST: Loss: 0.3412, Acc: 52.35%
# Epoch [2/500] - NEW BEST: Loss: 0.3412, Acc: 52.35%
# Epoch [3/500] - NEW BEST: Loss: 0.3097, Acc: 60.38%
# Epoch [3/500] - NEW BEST: Loss: 0.3097, Acc: 60.38%
# Epoch [4/500] - NEW BEST: Loss: 0.2944, Acc: 64.28%
# Epoch [4/500] - NEW BEST: Loss: 0.2944, Acc: 64.28%
# Epoch [5/500] - NEW BEST: Loss: 0.2819, Acc: 64.52%
# Epoch [5/500] - NEW BEST: Loss: 0.2819, Acc: 64.52%
# Epoch [6/500] - NEW BEST: Loss: 0.2497, Acc: 67.86%
# Epoch [6/500] - NEW BEST: Loss: 0.2497, Acc: 67.86%
# Epoch [8/500] - NEW BEST: Loss: 0.2473, Acc: 70.46%
# Epoch [8/500] - NEW BEST: Loss: 0.2473, Acc: 70.46%
# Epoch [9/500] - NEW BEST: Loss: 0.2283, Acc: 68.91%
# Epoch [9/500] - NEW BEST: Loss: 0.2283, Acc: 68.91%
# Epoch [12/500] - NEW BEST: Loss: 0.2105, Acc: 72.37%
# Epoch [12/500] - NEW BEST: Loss: 0.2105, Acc: 72.37%
# Epoch [14/500] - NEW BEST: Loss: 0.2053, Acc: 73.49%
# Epoch [14/500] - NEW BEST: Loss: 0.2053, Acc: 73.49%
# Epoch [15/500] - NEW BEST: Loss: 0.2038, Acc: 71.38%
# Epoch [15/500] - NEW BEST: Loss: 0.2038, Acc: 71.38%
# Epoch [19/500] - NEW BEST: Loss: 0.2036, Acc: 74.47%
# Epoch [19/500] - NEW BEST: Loss: 0.2036, Acc: 74.47%
# Epoch [20/500] - NEW BEST: Loss: 0.2007, Acc: 72.68%
# Epoch [20/500] - NEW BEST: Loss: 0.2007, Acc: 72.68%
# Epoch [21/500] - NEW BEST: Loss: 0.1992, Acc: 72.56%
# Epoch [21/500] - NEW BEST: Loss: 0.1992, Acc: 72.56%
# Epoch [23/500] - NEW BEST: Loss: 0.1978, Acc: 74.47%
# Epoch [23/500] - NEW BEST: Loss: 0.1978, Acc: 74.47%
# Epoch [24/500] - NEW BEST: Loss: 0.1851, Acc: 73.05%
# Epoch [24/500] - NEW BEST: Loss: 0.1851, Acc: 73.05%
# Epoch [26/500] - NEW BEST: Loss: 0.1786, Acc: 74.66%
# Epoch [26/500] - NEW BEST: Loss: 0.1786, Acc: 74.66%
# Epoch [29/500] - NEW BEST: Loss: 0.1759, Acc: 76.45%
# Epoch [29/500] - NEW BEST: Loss: 0.1759, Acc: 76.45%
# Epoch [31/500] - NEW BEST: Loss: 0.1706, Acc: 76.82%
# Epoch [31/500] - NEW BEST: Loss: 0.1706, Acc: 76.82%
# Epoch [33/500] - NEW BEST: Loss: 0.1668, Acc: 74.29%
# Epoch [33/500] - NEW BEST: Loss: 0.1668, Acc: 74.29%
# Epoch [36/500] - NEW BEST: Loss: 0.1595, Acc: 75.96%
# Epoch [36/500] - NEW BEST: Loss: 0.1595, Acc: 75.96%
# Epoch [39/500] - NEW BEST: Loss: 0.1532, Acc: 77.56%
# Epoch [39/500] - NEW BEST: Loss: 0.1532, Acc: 77.56%
# Epoch [40/500] - NEW BEST: Loss: 0.1513, Acc: 80.35%
# Epoch [40/500] - NEW BEST: Loss: 0.1513, Acc: 80.35%
# Epoch [45/500] - NEW BEST: Loss: 0.1497, Acc: 78.55%
# Epoch [45/500] - NEW BEST: Loss: 0.1497, Acc: 78.55%
# Epoch [46/500] - NEW BEST: Loss: 0.1360, Acc: 81.33%
# Epoch [46/500] - NEW BEST: Loss: 0.1360, Acc: 81.33%
# Epoch [58/500] - NEW BEST: Loss: 0.1345, Acc: 80.04%
# Epoch [58/500] - NEW BEST: Loss: 0.1345, Acc: 80.04%
# Epoch [59/500] - NEW BEST: Loss: 0.1294, Acc: 82.88%
# Epoch [59/500] - NEW BEST: Loss: 0.1294, Acc: 82.88%
# Epoch [60/500] - NEW BEST: Loss: 0.1262, Acc: 82.26%
# Epoch [60/500] - NEW BEST: Loss: 0.1262, Acc: 82.26%
# Epoch [65/500] - NEW BEST: Loss: 0.1237, Acc: 82.39%
# Epoch [65/500] - NEW BEST: Loss: 0.1237, Acc: 82.39%
# Epoch [69/500] - NEW BEST: Loss: 0.1189, Acc: 83.56%
# Epoch [69/500] - NEW BEST: Loss: 0.1189, Acc: 83.56%
# Epoch [71/500] - NEW BEST: Loss: 0.1172, Acc: 81.77%
# Epoch [71/500] - NEW BEST: Loss: 0.1172, Acc: 81.77%
# Epoch [72/500] - NEW BEST: Loss: 0.1167, Acc: 83.31%
# Epoch [72/500] - NEW BEST: Loss: 0.1167, Acc: 83.31%
# Epoch [73/500] - NEW BEST: Loss: 0.1061, Acc: 83.68%
# Epoch [73/500] - NEW BEST: Loss: 0.1061, Acc: 83.68%
# Early stopping at epoch 88
#
#
# Fold 4 Test Accuracy: 81.13%
# Fold 4 Test F1 Score: 0.8139
#
# ============================================================
# Fold 5/5
# ============================================================
# Train samples: 8072, Val samples: 2924
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.66701468 1.21575059 1.11723473]
# Early stopping at epoch 88
#
#
# Fold 4 Test Accuracy: 81.13%
# Fold 4 Test F1 Score: 0.8139
#
# ============================================================
# Fold 5/5
# ============================================================
# Train samples: 8072, Val samples: 2924
# Model parameters: 712,131
# Using Focal Loss with class weights: [0.66701468 1.21575059 1.11723473]
# Epoch [1/500] - NEW BEST: Loss: 0.3979, Acc: 42.65%
# Epoch [1/500] - NEW BEST: Loss: 0.3979, Acc: 42.65%
# Epoch [2/500] - NEW BEST: Loss: 0.3792, Acc: 49.18%
# Epoch [2/500] - NEW BEST: Loss: 0.3792, Acc: 49.18%
# Epoch [3/500] - NEW BEST: Loss: 0.3567, Acc: 42.72%
# Epoch [3/500] - NEW BEST: Loss: 0.3567, Acc: 42.72%
# Epoch [4/500] - NEW BEST: Loss: 0.3546, Acc: 54.24%
# Epoch [4/500] - NEW BEST: Loss: 0.3546, Acc: 54.24%
# Epoch [5/500] - NEW BEST: Loss: 0.3408, Acc: 50.58%
# Epoch [5/500] - NEW BEST: Loss: 0.3408, Acc: 50.58%
# Epoch [6/500] - NEW BEST: Loss: 0.3143, Acc: 54.82%
# Epoch [6/500] - NEW BEST: Loss: 0.3143, Acc: 54.82%
# Epoch [7/500] - NEW BEST: Loss: 0.3133, Acc: 61.05%
# Epoch [7/500] - NEW BEST: Loss: 0.3133, Acc: 61.05%
# Epoch [10/500] - NEW BEST: Loss: 0.2820, Acc: 62.24%
# Epoch [10/500] - NEW BEST: Loss: 0.2820, Acc: 62.24%
# Epoch [11/500] - NEW BEST: Loss: 0.2798, Acc: 65.94%
# Epoch [11/500] - NEW BEST: Loss: 0.2798, Acc: 65.94%
# Epoch [13/500] - NEW BEST: Loss: 0.2791, Acc: 64.06%
# Epoch [13/500] - NEW BEST: Loss: 0.2791, Acc: 64.06%
# Epoch [14/500] - NEW BEST: Loss: 0.2583, Acc: 69.84%
# Epoch [14/500] - NEW BEST: Loss: 0.2583, Acc: 69.84%
# Epoch [16/500] - NEW BEST: Loss: 0.2433, Acc: 69.12%
# Epoch [16/500] - NEW BEST: Loss: 0.2433, Acc: 69.12%
# Epoch [23/500] - NEW BEST: Loss: 0.2350, Acc: 72.16%
# Epoch [23/500] - NEW BEST: Loss: 0.2350, Acc: 72.16%
# Epoch [25/500] - NEW BEST: Loss: 0.2309, Acc: 69.25%
# Epoch [25/500] - NEW BEST: Loss: 0.2309, Acc: 69.25%
# Epoch [26/500] - NEW BEST: Loss: 0.2284, Acc: 69.12%
# Epoch [26/500] - NEW BEST: Loss: 0.2284, Acc: 69.12%
# Epoch [28/500] - NEW BEST: Loss: 0.2254, Acc: 72.67%
# Epoch [28/500] - NEW BEST: Loss: 0.2254, Acc: 72.67%
# Epoch [29/500] - NEW BEST: Loss: 0.2210, Acc: 71.24%
# Epoch [29/500] - NEW BEST: Loss: 0.2210, Acc: 71.24%
# Epoch [33/500] - NEW BEST: Loss: 0.2184, Acc: 72.30%
# Epoch [33/500] - NEW BEST: Loss: 0.2184, Acc: 72.30%
# Epoch [38/500] - NEW BEST: Loss: 0.2104, Acc: 71.41%
# Epoch [38/500] - NEW BEST: Loss: 0.2104, Acc: 71.41%
# Epoch [45/500] - NEW BEST: Loss: 0.2033, Acc: 73.73%
# Epoch [45/500] - NEW BEST: Loss: 0.2033, Acc: 73.73%
# Epoch [49/500] - NEW BEST: Loss: 0.1961, Acc: 75.55%
# Epoch [49/500] - NEW BEST: Loss: 0.1961, Acc: 75.55%
# Epoch [52/500] - NEW BEST: Loss: 0.1951, Acc: 76.33%
# Epoch [52/500] - NEW BEST: Loss: 0.1951, Acc: 76.33%
# Epoch [62/500] - NEW BEST: Loss: 0.1887, Acc: 75.00%
# Epoch [62/500] - NEW BEST: Loss: 0.1887, Acc: 75.00%
# Epoch [72/500] - NEW BEST: Loss: 0.1832, Acc: 75.03%
# Epoch [72/500] - NEW BEST: Loss: 0.1832, Acc: 75.03%
# Epoch [78/500] - NEW BEST: Loss: 0.1829, Acc: 77.22%
# Epoch [78/500] - NEW BEST: Loss: 0.1829, Acc: 77.22%
# Epoch [89/500] - NEW BEST: Loss: 0.1792, Acc: 76.85%
# Epoch [89/500] - NEW BEST: Loss: 0.1792, Acc: 76.85%
# Epoch [90/500] - NEW BEST: Loss: 0.1745, Acc: 76.06%
# Epoch [90/500] - NEW BEST: Loss: 0.1745, Acc: 76.06%
# Epoch [101/500] - NEW BEST: Loss: 0.1697, Acc: 77.09%
# Epoch [101/500] - NEW BEST: Loss: 0.1697, Acc: 77.09%
# Epoch [109/500] - NEW BEST: Loss: 0.1695, Acc: 80.06%
# Epoch [109/500] - NEW BEST: Loss: 0.1695, Acc: 80.06%
# Epoch [121/500] - NEW BEST: Loss: 0.1684, Acc: 80.71%
# Epoch [121/500] - NEW BEST: Loss: 0.1684, Acc: 80.71%
# Epoch [123/500] - NEW BEST: Loss: 0.1658, Acc: 79.48%
# Epoch [123/500] - NEW BEST: Loss: 0.1658, Acc: 79.48%
# Epoch [125/500] - NEW BEST: Loss: 0.1646, Acc: 79.89%
# Epoch [125/500] - NEW BEST: Loss: 0.1646, Acc: 79.89%
# Epoch [133/500] - NEW BEST: Loss: 0.1555, Acc: 79.82%
# Epoch [133/500] - NEW BEST: Loss: 0.1555, Acc: 79.82%
# Early stopping at epoch 148
#
#
# Fold 5 Test Accuracy: 82.80%
# Fold 5 Test F1 Score: 0.8309
# {'fold_1': {'train': {'accuracy': 83.11632870864462,
#                       'loss': 0.10620388363291618},
#             'val': {'accuracy': 85.05535055350553,
#                     'f1_score': 0.8525149794079536,
#                     'loss': 0.12052314484921786}},
#  'fold_2': {'train': {'accuracy': 87.6386518771331, 'loss': 0.0738680327729303},
#             'val': {'accuracy': 85.8641975308642,
#                     'f1_score': 0.8604713238667635,
#                     'loss': 0.11552784527437045}},
#  'fold_3': {'train': {'accuracy': 85.69594247560349,
#                       'loss': 0.08308883164016927},
#             'val': {'accuracy': 84.66334164588528,
#                     'f1_score': 0.8489554335593645,
#                     'loss': 0.10937615812701337}},
#  'fold_4': {'train': {'accuracy': 82.14971209213051,
#                       'loss': 0.11105391672071145},
#             'val': {'accuracy': 83.68355995055624,
#                     'f1_score': 0.8388962576647927,
#                     'loss': 0.10610790378772296}},
#  'fold_5': {'train': {'accuracy': 86.76907829534193,
#                       'loss': 0.07851820178036614},
#             'val': {'accuracy': 79.82216142270862,
#                     'f1_score': 0.8014572548001796,
#                     'loss': 0.1554905902594328}}}
#
# ============================================================
# Overall Test Results (5-Fold Ensemble)
# ============================================================
# Overall Test Accuracy: 82.89%
# Overall Test F1 Score: 0.8324
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.87      2198
#            1       0.70      0.90      0.79      1260
#            2       0.79      0.82      0.80      1264
#
#     accuracy                           0.83      4722
#    macro avg       0.82      0.84      0.82      4722
# weighted avg       0.85      0.83      0.83      4722
#
# ✅ Classification report saved to ./Class/classification_report.csv
# Early stopping at epoch 148
#
#
# Fold 5 Test Accuracy: 82.80%
# Fold 5 Test F1 Score: 0.8309
# {'fold_1': {'train': {'accuracy': 83.11632870864462,
#                       'loss': 0.10620388363291618},
#             'val': {'accuracy': 85.05535055350553,
#                     'f1_score': 0.8525149794079536,
#                     'loss': 0.12052314484921786}},
#  'fold_2': {'train': {'accuracy': 87.6386518771331, 'loss': 0.0738680327729303},
#             'val': {'accuracy': 85.8641975308642,
#                     'f1_score': 0.8604713238667635,
#                     'loss': 0.11552784527437045}},
#  'fold_3': {'train': {'accuracy': 85.69594247560349,
#                       'loss': 0.08308883164016927},
#             'val': {'accuracy': 84.66334164588528,
#                     'f1_score': 0.8489554335593645,
#                     'loss': 0.10937615812701337}},
#  'fold_4': {'train': {'accuracy': 82.14971209213051,
#                       'loss': 0.11105391672071145},
#             'val': {'accuracy': 83.68355995055624,
#                     'f1_score': 0.8388962576647927,
#                     'loss': 0.10610790378772296}},
#  'fold_5': {'train': {'accuracy': 86.76907829534193,
#                       'loss': 0.07851820178036614},
#             'val': {'accuracy': 79.82216142270862,
#                     'f1_score': 0.8014572548001796,
#                     'loss': 0.1554905902594328}}}
#
# ============================================================
# Overall Test Results (5-Fold Ensemble)
# ============================================================
# Overall Test Accuracy: 82.89%
# Overall Test F1 Score: 0.8324
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.87      2198
#            1       0.70      0.90      0.79      1260
#            2       0.79      0.82      0.80      1264
#
#     accuracy                           0.83      4722
#    macro avg       0.82      0.84      0.82      4722
# weighted avg       0.85      0.83      0.83      4722
#
# ✅ Classification report saved to ./Class/classification_report.csv
# ✅ Training plot saved to ./Class/training_curves_classification.png
#
# Training completed successfully!
# Best models saved for classification task
# Collected features from 5 folds
# Predictions shape: (4722,)
# Using Focal Loss for classification with StratifiedGroupKFold cross-validation

# %%
print("Model Architecture Summary:")
print(f"Model: {model.__class__.__name__}")

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

from torchview import draw_graph

# 1. Define and eval model
model_viz = ClassificationModel(input_dim=2550, latent_dim=64, num_classes=3)
model_viz.eval()

# 2. Draw graph
graph = draw_graph(
    model_viz,
    input_size=(1, 2550),
    expand_nested=True,
    graph_name="ClassificationModel",
    roll=False,
)

# 3. Save the .gv file
os.makedirs('./Class', exist_ok=True)
gv_path = graph.visual_graph.save(filename="./Class/ClassificationModel.gv")
print(f"✅ Graph saved to ./Class/ClassificationModel.gv")

graph.visual_graph
# Out:
# Model Architecture Summary:
# Model: ClassificationModel
# Total parameters: 712,131
# Trainable parameters: 712,131
# ✅ Graph saved to ./Class/ClassificationModel.gv

# %%
from graphviz import Source

# Load the .gv file
src = Source.from_file('./Class/ClassificationModel.gv')

# Render it as PNG (creates graph.png)
src.render(filename='./Class/ClassificationModel', format='png', cleanup=True)
# Out:
# 'Class/ClassificationModel.png'

# %%
# ========== EVALUATION ON TEST SET ==========

print("\n" + "="*60)
print("EVALUATION: Loading data and predicting with all 5 folds")
print("="*60)

# Load and prepare data using the same split method as training
X, y, groups, scaler = prepare_data(n_splits=5)
X, X_test, y, y_test, groups, groups_test = split_data(X, y, groups, test_size=0.3, random_state=42)

# Load all 5 trained models and make predictions
test_dataset = HyperspectralDataset(X_test, y_test, mask_ratio=0.15)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

all_predictions = []
all_features = []

for fold in range(1, 6):
    checkpoint_path = f'./Class/best_classification_model_fold{fold}.pth'
    
    if not os.path.exists(checkpoint_path):
        print(f"Warning: Checkpoint {checkpoint_path} not found, skipping fold {fold}")
        continue
    
    # Load model
    model_eval = ClassificationModel(input_dim=X_test.shape[1], latent_dim=64, num_classes=len(np.unique(y_test))).to(device)
    model_eval.load_state_dict(torch.load(checkpoint_path))
    model_eval.eval()
    
    fold_predictions = []
    fold_features = []
    
    with torch.no_grad():
        for batch in test_loader:
            masked_spectrum = batch['masked_spectrum'].to(device)
            outputs = model_eval(masked_spectrum)
            _, predicted = torch.max(outputs['class_logits'].data, 1)
            
            fold_predictions.extend(predicted.cpu().numpy())
            fold_features.extend(outputs['features'].cpu().numpy())
    
    all_predictions.append(fold_predictions)
    all_features.append(fold_features)
    print(f"Fold {fold} predictions collected")

# Ensemble predictions (hard voting - average and round)
ensemble_predictions = np.round(np.mean(all_predictions, axis=0)).astype(int)
y_true = y_test.astype(int)
y_pred = ensemble_predictions

# Calculate metrics
cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

AA = per_class_acc.mean()
OA = (cm.diagonal().sum()) / cm.sum()

print("\n" + "="*60)
print("TEST SET RESULTS (5-Fold Ensemble)")
print("="*60)
print("OA:", OA)
print("AA:", AA)

print("\nClassification report:")
print(classification_report(y_true, y_pred))
# Out:
# ============================================================
# EVALUATION: Loading data and predicting with all 5 folds
# ============================================================
# Loading dataset...
# Note: load_dataset now loads from CSV files in ../data/ directory
# Loading data from CSV files...
# Loading df_field_b.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_field_g.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_field_g.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_screenh_b.csv...
#   Shape: (3780, 2550), Classes: [0 1 2], Groups: 10
# Loading df_screenh_b.csv...
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 11
# Loading df_screenh_g.csv...
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 11
# Loading df_screenh_g.csv...
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 10
#
# Combined data shape: (15718, 2550)
# Combined classes: [0 1 2]
# Total groups: 11
# After removing NaN - Data shape: (15718, 2550)
# Original label range: [0 1 2]
#   Shape: (4079, 2550), Classes: [0 1 2], Groups: 10
#
# Combined data shape: (15718, 2550)
# Combined classes: [0 1 2]
# Total groups: 11
# After removing NaN - Data shape: (15718, 2550)
# Original label range: [0 1 2]
# Spectral bands/features: 2550
# Training samples: 9364
# Test samples: 6354
# Training classes: [0 1 2]
# Test classes: [0 1 2]
# Total samples: 15718
# Using StratifiedGroupKFold with 5 folds
# Training samples: 10996, Validation samples: 4722
# Spectral bands/features: 2550
# Training samples: 9364
# Test samples: 6354
# Training classes: [0 1 2]
# Test classes: [0 1 2]
# Total samples: 15718
# Using StratifiedGroupKFold with 5 folds
# Training samples: 10996, Validation samples: 4722
# Fold 1 predictions collected
# Fold 2 predictions collected
# Fold 1 predictions collected
# Fold 2 predictions collected
# Fold 3 predictions collected
# Fold 4 predictions collected
# Fold 3 predictions collected
# Fold 4 predictions collected
# Fold 5 predictions collected
#
# ============================================================
# TEST SET RESULTS (5-Fold Ensemble)
# ============================================================
# OA: 0.82570944515036
# AA: 0.8322637423016364
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88      2198
#            1       0.70      0.89      0.78      1260
#            2       0.79      0.81      0.80      1264
#
#     accuracy                           0.83      4722
#    macro avg       0.82      0.83      0.82      4722
# weighted avg       0.85      0.83      0.83      4722
#
# Fold 5 predictions collected
#
# ============================================================
# TEST SET RESULTS (5-Fold Ensemble)
# ============================================================
# OA: 0.82570944515036
# AA: 0.8322637423016364
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88      2198
#            1       0.70      0.89      0.78      1260
#            2       0.79      0.81      0.80      1264
#
#     accuracy                           0.83      4722
#    macro avg       0.82      0.83      0.82      4722
# weighted avg       0.85      0.83      0.83      4722
